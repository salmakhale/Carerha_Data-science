# %% [markdown]
# <a href="https://colab.research.google.com/github/salmakhale/Carerha_Data-science/blob/main/Hypothesis_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Hypothesis Testing (Validate True/False)

import pandas as pd

import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt

np.random.seed(42)

sample_df = pd.DataFrame({

    'id' : range(1,1001),

    'age': np.random.randint(17,80, size = 1000),

    'gender': np.random.choice(['Male', 'Female'], size = 1000),

    'income': np.random.normal(50000, 10000, size = 1000)

})

sample_df
# Out:
#        id  age  gender        income
# 0       1   55    Male  54296.182191
# 1       2   68    Male  52076.876872
# 2       3   45  Female  52715.788372
# 3       4   31  Female  37232.514242
# 4       5   59  Female  39189.434596
# ..    ...  ...     ...           ...
# 995   996   77  Female  35424.485005
# 996   997   22    Male  46907.909230
# 997   998   34  Female  42478.435944
# 998   999   67    Male  53191.745104
# 999  1000   21  Female  63404.504460
#
# [1000 rows x 4 columns]

# %%
hypothesis_paramater = 60000

income_mean = sample_df['income'].mean()

income_std = sample_df['income'].std()

z_score = (hypothesis_paramater - income_mean) / income_std

print(f'z_score = {z_score}')

from scipy.stats import norm

p_value = norm.cdf(z_score, loc = 0, scale = 1)

print(f'p_value = {p_value}')

if p_value < 0.05:

  print('Reject H0')

else:

  print('Failed to Reject H0')
# Out:
# z_score = 0.9139629317733982
# p_value = 0.8196318381289214
# Failed to Reject H0

# %%
male_income = sample_df[sample_df['gender'] == 'Male']['income']

female_income = sample_df[sample_df['gender'] == 'Female']['income']

from scipy.stats import ttest_ind

t_score, p_value = ttest_ind(male_income, female_income)

if p_value < 0.05:

  print('Reject H0')

else:

  print('Failed to Reject H0')
# Out:
# Failed to Reject H0
