# %% [markdown]
# <a href="https://colab.research.google.com/github/salmakhale/Carerha_Data-science/blob/main/ploty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

folder_path ='/content/drive/MyDrive/Data/Data Analysis Project - Practice'

files = os.listdir(folder_path)
print("Files in the folder:", files)

for filename in os.listdir(folder_path):
    if filename.endswith('.csv') or filename.endswith('.xlsx'):
        file_path = os.path.join(folder_path, filename)
        try:
            data = pd.read_csv(file_path) if filename.endswith('.csv') else pd.read_excel(file_path)
            print(f"Data reading: {filename}")


            print(data.info())
            print(data.head())


            input(" Enter")

        except Exception as e:
            print(f"error try agian {filename}: {e}")
# Out:
# Files in the folder: ['Visits.xlsx', 'Products.csv', 'Outlets.csv', 'Warehouses.xlsx', 'Sales.xlsx', 'Reps List.xlsx', 'Targets April 2021.xlsx']
# Data reading: Visits.xlsx
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219648 entries, 0 to 219647
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   DB Name              219648 non-null  object
#  1   Sales Rep ID         219648 non-null  int64
#  2   Sales Rep Name       219648 non-null  object
#  3   Date                 219648 non-null  datetime64[ns]
#  4   Classification       219648 non-null  object
#  5   Store Code           219648 non-null  int64
#  6   Visit Starting Time  219648 non-null  object
#  7   Visit Ending Time    219648 non-null  object
#  8   Sale Amount          875 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 15.1+ MB
# None
# ...

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

file_path ='/content/drive/MyDrive/Data/Data Analysis Project - Practice/Outlets.csv'

df =pd.read_csv(file_path)

# df.info()
#df.head()

#df['Outlet Name'].unique()
df['Outlet Name'].str.replace('ابو', 'أبو', regex=False)
df['Outlet Type'].str.replace('تجزئة', 'تجزئه',regex=False)
#name_counts = df['Outlet Name'].value_counts()
#print(name_counts)
#unique_count = len(unique_names)
#print(unique_count)
#name_counts = df['Outlet Name'].value_counts()
#print(name_counts)

# print(df['Outlet Name'].duplicated().sum())
# print(df['Employee_Name'].duplicated().sum())

#print(df.groupby('Warehouse Code')['Warehouse Name'].nunique())

# duplicate_warehouse_codes = df['Warehouse Code'].duplicated(keep=False)

# if duplicate_warehouse_codes.any():
#     print("Warehouse Codes reapeted:")
#     print(df[duplicate_warehouse_codes][['Warehouse Code', 'Warehouse Name']])
# else:
#     print("No repeat Warehouse Code.")

# duplicate_entries = df[df.duplicated(subset=['Warehouse Code', 'Warehouse Name'], keep=False)]
# print(duplicate_entries)

# warehouse_counts = df.groupby(['Warehouse Code', 'Warehouse Name']).size().reset_index(name='Count')
# print(warehouse_counts)

#class_distribution = df.groupby('Outlet Name')['Outlet Class'].unique()
#print(class_distribution)


# pd.pivot_table(
#     df,
#     index=['Employee_Code', 'Warehouse Code'],
#     values=['Outlet Type'],
#     aggfunc='sum'
#     )

# cols = list(df.nunique().sort_values().index[:8])
# plt.figure(figsize=(30,20))
# for n , col in enumerate(cols) :
#     plt.subplot(3,3,n+1)
#     sns.countplot(data=df,x=col)


# plt.figure(figsize=(10,6))
# sns.countplot(data=df,x='Outlet Type',hue='Warehouse Code')
# Out:
#   File "<ipython-input-49-b9b60f1e51df>", line 15
#     (df['Outlet Name'].str.replace('ابو', 'أبو', regex=False),inplace=True)
#                                                               ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
file_path ='/content/drive/MyDrive/Data/Data Analysis Project - Practice/Products.csv'

df =pd.read_csv(file_path)

#df.info()
#df.head()

# df.isnull().sum()
df = df.drop(columns=['Unnamed: 6', 'Unnamed: 7'])
# df.isnull().sum().sort_values().plot(kind='bar')
#df.isnull().all(axis=1)

يب

#missing_data = df.isnull().sum() / len(df) * 100
#missing_data

#invalid_prices = df[df['Price'] < 0]
#invalid_prices
# Out:
#      Product ID  Product Code         Product Name   Category  \
# 0           1.0       96938.0      Detergent 120ml  Detergent
# 1           2.0       52554.0  Soap 125gm - Normal       Soap
# 2           3.0       22134.0     Soap 125gm - Red       Soap
# 3           4.0       75443.0    Soap 125gm - blue       Soap
# 4           5.0       99185.0  Soap 125gm - yellow       Soap
# ..          ...           ...                  ...        ...
# 118         NaN           NaN                  NaN        NaN
# 119         NaN           NaN                  NaN        NaN
# 120         NaN           NaN                  NaN        NaN
# 121         NaN           NaN                  NaN        NaN
# 122         NaN           NaN                  NaN        NaN
#
#          subcategory  Price  29034  96938
# 0    Detergent 120ml  19.84  33590  52554
# 1             BS 125   8.33  33591  22134
# 2             BS 125   8.33  33592  75443
# 3             BS 125   8.33  33593  99185
# ...

# %%
file_path ='/content/drive/MyDrive/Data/Data Analysis Project - Practice/Reps List.xlsx'

df =pd.read_excel(file_path)

#df.info()
df.head()

#df.duplicated().sum()
#df['ZONE'].value_counts().plot(kind='bar', title='Distribution by Zone')

# pd.pivot_table(
#     df,
#     index=['Name','Role'],
#     values=['ZONE'],
#     aggfunc='max'
#     )
sns.countplot(x='Role', hue='ZONE', data=df)


# pd.pivot_table(
#     df,
#     index=['Username','ZONE'],
#     values=['Distributor'],
#     aggfunc='max'
#     )
sns.countplot(x='ZONE', hue='Username', data=df)
# Out:
# <Axes: xlabel='Role', ylabel='count'>

# %%
file_path ='/content/drive/MyDrive/Data/Data Analysis Project - Practice/Targets April 2021.xlsx'

df =pd.read_excel(file_path)

df.info()

df.columns = ['Target1', 'Target2']
df

targets=pd.read_excel('/content/drive/MyDrive/Data/Data Analysis Project - Practice/Targets April 2021.xlsx',sheet_name='Targets')
targets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   asdfasfd    2 non-null      object
#  1   asdfasfd.1  2 non-null      object
# dtypes: object(2)
# memory usage: 160.0+ bytes
#     ID Username             Name        ZONE Distributor  Target   AC  \
# 0    1  Rep0003  Mohamed Hussein       Delta        DB 1  195000  130
# 1    2  Rep0004       Thabet Ali       Delta        DB 2  460000  120
# 2    3  Rep0005     Amgad Mohsen       Upper        DB 3  175000  110
# 3    4  Rep0006            Baher       Delta        DB 4  490000  190
# 4    5  Rep0007             Omar  Cairo/Giza        DB 5  350000   60
# 5    6  Rep0008           Yasser       Delta        DB 6  400000  200
# 6    7  Rep0009            Osama       Upper        DB 7  320000  175
# 7    8  Rep0010            Amgad       Delta        DB 4  330000  175
# ...

# %%
file_path ='/content/drive/MyDrive/Data/Data Analysis Project - Practice/Sales.xlsx'

df =pd.read_excel(file_path)

# df.info()
# df.head()

# df.duplicated().sum()

# df['Calculated_Total'] = df['Quantity'] * df['Price_Per_Piece']
# discrepancies = df[df['Total Price'] != df['Calculated_Total']]
# print(discrepancies)

# for column in ['Date', 'Sub_Db_Name', 'Username', 'Name_Of_The_User', 'Outlet_Id']:
#     unique_values = df[column].unique()
#     print(f"{column}: {len(unique_values)}")
#     print(f"{unique_values}\n")

# print(df['Date'].min(), "to", df['Date'].max())
# df = df.sort_values(by='Date')
# df['Date_Diff'] = df['Date'].diff()
# gaps = df[df['Date_Diff'] > pd.Timedelta(days=1)]
# print(gaps[['Date', 'Date_Diff']])

# import matplotlib.pyplot as plt
# pd.pivot_table(
#     data = df,
#     index = ['Date','Quantity'],
#     values = 'Total Price',
#     aggfunc = 'sum'
# )
# df.groupby(df['Date'].dt.to_period('M'))['Total Price'].sum().plot(kind='line')
# plt.title('Total price per month  ')
# plt.xlabel('Date')
# plt.ylabel('Total price')
# plt.show()


# pd.pivot_table(
#     df, index=['Name_Of_The_User','PRODUCT_CODE'], values=['Quantity'], aggfunc='max' )
# plt.figure(figsize=(10,6))
# sns.barplot(data=df,x ='Name_Of_The_User',y='Quantity',)

# pd.pivot_table(
# df, index=['PRODUCT_CODE','Quantity'], values=['Total Price'], aggfunc='sum' )
sns.scatterplot(data=df,x='Quantity',y='Total Price')

# pd.pivot_table(
#     df, index=['Sub_Db_Name','Product Name	'], values=[' Price_Per_Piece'], aggfunc='sum' )
# sns.countplot(data=df,x='Sub_Db_Name',hue='Product Name')



# plt.hist(df['Total Price'], bins=20)
# plt.xlabel('Total Price')
# plt.ylabel('Frequency')
# plt.title('Total Price Distribution')
# plt.show()
# Out:
# <Axes: xlabel='Quantity', ylabel='Total Price'>

# %%
from datetime import datetime

file_path ='/content/drive/MyDrive/Data/Data Analysis Project - Practice/Visits.xlsx'

df =pd.read_excel(file_path)

# df.info()
# df.head()

# df['Visit Starting Time'] = pd.to_datetime(df['Visit Starting Time'], errors='coerce')
# df['Visit Ending Time'] = pd.to_datetime(df['Visit Ending Time'], errors='coerce')
# print(df['Visit Starting Time'].unique())
# print(df[df['Visit Starting Time'].isna()])

# today = datetime.today().date()
# df['Visit Starting Time'] = pd.to_datetime(df['Visit Starting Time'].astype(str) + ' ' + str(today))
# df['Visit Ending Time'] = pd.to_datetime(df['Visit Ending Time'].astype(str) + ' ' + str(today))
# df['Visit Starting Time'].dtypes

# time_difference = df['Visit Ending Time'] - df['Visit Starting Time']
# time_difference


#df['Sale Amount'].unique()

# pd.pivot_table(
#      df, index=['Sales Rep ID','Classification'], values=['Store Code'], aggfunc='mean' )
# sns.countplot(data=df,x='Classification',hue='Sales Rep ID')

# pd.pivot_table(
#      df, index=['Visit Starting Time','Visit Ending Time'], values=['Classification'], aggfunc='sum' )
sns.barplot(data=df,x='Sales Rep ID',hue='Classification')
# Out:
# <Axes: xlabel='Sales Rep ID'>

# %%
##still working on this##

df1=pd.read_excel('/content/drive/MyDrive/Data/Data Analysis Project - Practice/Sales.xlsx')
df1
#first piviotable to find null in secound data(sale amount)
# df2=pd.read_excel('/content/drive/MyDrive/Data/Data Analysis Project - Practice/Visits.xlsx')

# merged_df = pd.merge(df1, df2, how='outer', left_on=['Date', 'Sub_Db_Name', 'Name_Of_The_User', 'Outlet_Id'],
#                      right_on=['Date', 'DB Name', 'Sales Rep Name', 'Store Code'])

# merged_df.info()
# merged_df.head()
# Out:
#              Date Sub_Db_Name Username Name_Of_The_User  Outlet_Id  \
# 0      2020-01-01        DB 4  Rep0010            Amgad         81
# 1      2020-01-01        DB 4  Rep0010            Amgad         81
# 2      2020-01-01        DB 4  Rep0010            Amgad         81
# 3      2020-01-01        DB 4  Rep0010            Amgad         81
# 4      2020-01-01        DB 4  Rep0010            Amgad         81
# ...           ...         ...      ...              ...        ...
# 219789 2020-09-30        DB 7  Rep0011        محمد احمد        933
# 219790 2020-09-30        DB 1  Rep0003  Mohamed Hussein        202
# 219791 2020-09-30        DB 1  Rep0013           Rep 13       4964
# 219792 2020-09-30        DB 1  Rep0013           Rep 13       4964
# 219793 2020-09-30        DB 1  Rep0013           Rep 13       4964
#
#         PRODUCT_CODE                              Product Name  Quantity  \
# 0              96938                           Detergent 120ml        48
# ...

# %%
file_path ='/content/drive/MyDrive/Data/Data Analysis Project - Practice/Warehouses.xlsx'

df =pd.read_excel(file_path)

# df.info()
#df.head()

#print(df['Warehouse Name'].unique())
#print(df['Region'].unique())

#duplicates = df.duplicated(subset=['Warehouse Name', 'Code'])
#print(df[duplicates])

#df['Region'] = df['Region'].str.strip()
# df

# pd.pivot_table(
#       df, index=['Warehouse Name','Code'], values=['Region'], aggfunc='sum')
# sns.countplot(data=df,x='Code',hue='Region')



import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

for column in ['Code', 'Region']:
    fig = px.line(df, x='Warehouse Name', y=column, title=f'Warehouses - {column}', markers=True)
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
