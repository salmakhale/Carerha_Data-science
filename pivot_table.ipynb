# %% [markdown]
# <a href="https://colab.research.google.com/github/salmakhale/Carerha_Data-science/blob/main/pivot_table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import pandas as pd
import os

#Get folder path
folder_path ='/content/drive/MyDrive/Data/Sales'

#Get files in folder
files = os.listdir(folder_path)

#Get to read each file seperately
dfs =[]
for filename in files :
  #create flie_path
  file_path = folder_path + '/' + filename
  df = pd.read_excel(file_path)
  dfs.append(df)

#combined all Dataframs into one df
combined_df = pd.concat(dfs, ignore_index='True')
combined_df
# Out:
#            City       Date   Sales  StoreID
# 0         Cairo 2014-01-01    9.83      982
# 1         Cairo 2014-01-01   28.18      983
# 2         Cairo 2014-01-01    6.83      982
# 3         Cairo 2014-01-01   43.90      982
# 4         Cairo 2014-01-01   17.16      980
# ...         ...        ...     ...      ...
# 501085  Oakland 2015-12-31   34.51      983
# 501086  Oakland 2015-12-31    8.85      980
# 501087  Oakland 2015-12-31  185.27      981
# 501088  Oakland 2015-12-31  154.18      983
# 501089  Oakland 2015-12-31  151.73      981
#
# [501090 rows x 4 columns]

# %%
pd.pivot_table(
    combined_df,
    index= 'City' ,
    columns= 'StoreID',
    values='Sales',
    aggfunc='sum'
)
# Out:
# StoreID         980         981         982         983
# City
# Cairo    5380581.17  5364473.36  5326665.43  5398512.06
# Oakland  5380581.17  5364473.36  5402127.14  5398512.06

# %%
#Read Multiple Sheets from Excel Files

file_path ='/content/drive/MyDrive/Data/Advanced DAX.xlsx'
df= pd.read_excel(file_path, sheet_name=pd.ExcelFile(file_path).sheet_names)

# %%
type(df['Sales'])
# Out:
# pandas.core.frame.DataFrame
